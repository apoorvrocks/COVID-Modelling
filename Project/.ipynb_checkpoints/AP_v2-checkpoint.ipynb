# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import warnings
from scipy.optimize import dual_annealing,minimize,minimize_scalar
from datetime import datetime
np.set_printoptions(precision=5)

# %%
## global Variables
alpha = 1/5.8
gamma = 1/5
epsilon = 0.66

# %%
## sorts sero data,population data and removes rows not present in time series data
## the order of districts after this is same in all the tables
sero1 = pd.read_csv('seroprevalence2.csv')
sero1 = sero1.iloc[:-1,:]
sero1.drop(sero1.loc[sero1['Unit']=='Bengaluru Urban Conglomerate'].index, inplace=True)
sero1.sort_values('Unit',inplace = True)
#print(sero1['Unit'].values)
#sero1 = sero1.iloc[8:,:]


sero2 = pd.read_csv('seroprevalence-round2.csv')
sero2 = sero2.iloc[:-1,:]
sero2.drop(sero2.loc[sero2['Unit']=='Bengaluru Urban Conglomerate'].index, inplace=True)
sero2.sort_values('Unit',inplace = True)
#sero2 = sero2.iloc[:,:]

tests = pd.read_csv('tests.csv')
population = pd.read_csv('population.csv')
population.sort_values('district',inplace = True)
#print(population['district'].values)
pop = np.array(population.loc[:,'population'].to_list())
#population = population.iloc[8:,:]

vaccination = pd.read_csv('vaccination2.csv')
vaccination.rename( columns={'Unnamed: 0':'Date'}, inplace=True )
end_idx = np.where( vaccination['Date'] == 'Dose_2')[0][0]
vacc = (vaccination.iloc[0:end_idx,2:].to_numpy()).astype(int)


tinf = pd.read_csv('timeseries_TINF.csv')
trec = pd.read_csv('timeseries_TREC.csv')
tdec = pd.read_csv('timeseries_TDEC.csv')
tinf = tinf.iloc[:,:-2]
trec = trec.iloc[:,:-2]
tdec = tdec.iloc[:,:-2]
tinf = (tinf.iloc[:,1:].to_numpy()).astype(int)
trec = (trec.iloc[:,1:].to_numpy()).astype(int)
tdec = (tdec.iloc[:,1:].to_numpy()).astype(int)

bengaluru_urban_total_pop = np.sum(pop[0:8]) + pop[12]
bbmp_inf = np.zeros((np.shape(tinf)[0],8))
bbmp_rec = np.zeros((np.shape(trec)[0],8))
bbmp_dec = np.zeros((np.shape(tdec)[0],8))
bbmp_vacc = np.zeros((np.shape(vacc)[0],8))

for i in range(0,8):
    bbmp_inf[:,i] = (pop[i]/bengaluru_urban_total_pop)* tinf[:,4]
    bbmp_rec[:,i] = (pop[i]/bengaluru_urban_total_pop)* trec[:,4]
    bbmp_dec[:,i] = (pop[i]/bengaluru_urban_total_pop)* tdec[:,4]
    bbmp_vacc[:,i] = (pop[i]/bengaluru_urban_total_pop)* vacc[:,4]

tinf[:,4] = (pop[12]/bengaluru_urban_total_pop)* tinf[:,4]
trec[:,4] = (pop[12]/bengaluru_urban_total_pop)* trec[:,4]
tdec[:,4] = (pop[12]/bengaluru_urban_total_pop)* tdec[:,4]
vacc[:,4] = (pop[12]/bengaluru_urban_total_pop)* vacc[:,4]

tinf = np.append(bbmp_inf,tinf,axis = 1)
trec = np.append(bbmp_rec,trec,axis = 1)
tdec = np.append(bbmp_dec,tdec,axis = 1)
vacc = np.append(bbmp_vacc,vacc,axis = 1)
print(vacc)
# Out:
# [[5.19894e+02 2.52547e+02 9.56267e+02 ... 2.84400e+03 3.39000e+02
#   3.82420e+04]
#  [4.20941e+02 2.04479e+02 7.74259e+02 ... 0.00000e+00 0.00000e+00
#   1.52230e+04]
#  [3.37990e+02 1.64184e+02 6.21682e+02 ... 1.51000e+02 3.42000e+02
#   3.45830e+04]
#  ...
#  [7.81196e+05 3.79479e+05 1.43689e+06 ... 9.06787e+05 4.55307e+05
#   3.18838e+07]
#  [7.92106e+05 3.84778e+05 1.45696e+06 ... 9.25826e+05 4.66433e+05
#   3.26070e+07]
#  [7.98646e+05 3.87955e+05 1.46899e+06 ... 9.43898e+05 4.74304e+05
#   3.31508e+07]]

# %%
## returns S0,E0,I0,R0 from sero data on 11th Oct or on 1st March according to flag
def initial_conditions(flag):
    
    
    if flag == 1:
        
        I0 = np.array(sero1.loc[:,'% active infection'].to_list())
        I0 = (0.01*np.multiply(pop,I0)).astype(int)
        R0 = np.array(sero1.loc[:,'% IgG against SARS-CoV2'].to_list())
        R0 = (0.01*np.multiply(pop,R0)).astype(int)
        CIR0 = np.array(sero1.loc[:,'CIR'].to_list())
        end_idx = 208
        start_idx = 203  ## index of 11th oct in timeseries
        
    elif flag == 3:
        
        I0 = np.zeros(30)
        R0 = np.array(sero2.loc[:,'%-IgG against SARS-CoV2'].to_list())
        R0 = (0.01*np.multiply(pop,R0)).astype(int)
        CIR0 = np.array(sero2.loc[:,'CIR'].to_list())
        start_idx = 344  ## index of 1st march in timeseries
        end_idx = 349
   
    E0 = np.zeros(np.size(I0))
    
    for idx in range(start_idx,end_idx):
        E0 = E0 + np.mean(tinf[idx-6:idx+1,:],axis = 0) -  np.mean(trec[idx-6:idx+1,:],axis = 0) - np.mean(tdec[idx-6:idx+1,:],axis = 0)
    
    #E0 = 1/7*(np.array(Tinf.iloc[1:,end_idx].to_list()) - np.array(Tinf.iloc[1:,start_idx].to_list()))
    E0 = (0.2*np.multiply(E0,CIR0)).astype(int) ## average of infections from 11th to 15th
    S0 = pop - I0 - E0 - R0
    return S0,E0,I0,R0,CIR0,pop

# %%
CIR0 = initial_conditions(1)[4]

# %%
## returns CIR(t) for a given district 
def get_CIR_t(CIR0,flag):
    
    if flag == 1:
        start_idx = np.where(tests['Date'] == '11-10-2020')[0][0]
        end_idx = np.where(tests['Date'] == '01-11-2020')[0][0]
    elif flag == 2:
        start_idx = np.where(tests['Date'] == '01-11-2020')[0][0]
        end_idx = np.where(tests['Date'] == '28-02-2021')[0][0]
    elif flag == 3:
        start_idx = np.where(tests['Date'] == '28-02-2021')[0][0]
        end_idx = np.where(tests['Date'] == '15-03-2021')[0][0]
    elif flag == 4:
        start_idx = np.where(tests['Date'] == '15-03-2021')[0][0]
        end_idx = np.where(tests['Date'] == '07-04-2021')[0][0]    
    duration = end_idx - start_idx + 1 ## inclusive of both start and end
    T_t = tests['Daily Samples Tested'].values
    T0 =  T_t[start_idx]
    T_t = T_t[start_idx:end_idx+1]
    #T_t = np.diff(T_t,prepend = T0)
    CIR_t = np.zeros(duration)
    
    for j in range(duration):
        if j<7:
            CIR_t[j] = CIR0*T0/np.mean(T_t[0:j+1])
        elif j!=duration-1:
            CIR_t[j] = CIR0*T0/np.mean(T_t[j-6:j+1]) 
        elif j == duration-1:
            CIR_t[j] = CIR0*T0/np.mean(T_t[j-6:]) 
    
    return CIR_t

# %%
get_CIR_t(CIR0[5],1)
# Out:
# array([32.     , 27.24596, 25.30591, 24.97856, 24.73364, 24.76923,
#        24.65435, 24.66042, 24.93948, 25.13606, 25.04531, 24.95797,
#        24.55743, 24.71417, 25.16144, 26.34643, 27.24512, 27.52873,
#        27.74848, 28.23654, 27.95634, 27.40889])

# %%
## returns no of infections according to duration 
def get_c_t(idx,flag):
    
    if flag == 1:
        start_idx = np.where(tests['Date'] == '11-10-2020')[0][0]
        end_idx = np.where(tests['Date'] == '01-11-2020')[0][0]
    elif flag == 2:
        start_idx = np.where(tests['Date'] == '01-11-2020')[0][0]
        end_idx = np.where(tests['Date'] == '28-02-2021')[0][0]
    elif flag == 3:
        start_idx = np.where(tests['Date'] == '28-02-2021')[0][0]
        end_idx = np.where(tests['Date'] == '15-03-2021')[0][0]
    elif flag == 4:
        start_idx = np.where(tests['Date'] == '15-03-2021')[0][0]
        end_idx = np.where(tests['Date'] == '07-04-2021')[0][0]
           
    duration = end_idx - start_idx + 1   ## inclusive of both start and end
    C_t = tinf[start_idx:end_idx+1,idx] - trec[start_idx:end_idx+1,idx] - tdec[start_idx:end_idx+1,idx]
    #C_t = tinf.iloc[:,1+idx].to_numpy()
    #print(np.shape(C_t))
    #cases_start = C_t[start_idx] - C_t[start_idx-1]
    #C_t = C_t[start_idx:end_idx+1]
    #C_t = np.diff(C_t,prepend = cases_start)
    c_t = C_t/2
    
    for j in range(duration):
        
        if j== 0:
            c_t[j] = C_t[j]
        elif j<7:
            c_t[j] = np.mean(C_t[0:j+1])
        elif j!=duration-1:
            c_t[j] = np.mean(C_t[j-6:j+1]) 
        elif j==duration-1:
            c_t[j] = np.mean(C_t[j-6:]) 
    return c_t

# %%
get_c_t(5,1)
# Out:
# array([13209.21673, 12697.06346, 12410.40222, 12226.40796, 11936.21558,
#        11657.67316, 11381.37891, 10797.99726, 10294.75127,  9721.91535,
#         9080.7109 ,  8452.91205,  7763.98369,  7051.04443,  6307.65957,
#         5568.20701,  4969.63236,  4478.65993,  4114.71295,  3885.23898,
#         3724.66976,  3696.8457 ])

# %%
## returns vaccinations for a given district
def get_v_t(idx):
    
    #Total_V_t = data_preprocessing()[-3]
    #print(Total_V_t)
    #print(V_t)
    V_t = vacc[:,idx]
    V_t = np.insert(V_t,13,np.mean(V_t[6:13]))
    V_t = np.insert(V_t,14,np.mean(V_t[7:14]))
    V_t = np.insert(V_t,36,np.mean(V_t[30:36]))
    V_t = np.insert(V_t,40,np.mean(V_t[34:40]))
    V_t = np.insert(V_t,41,np.mean(V_t[34:41]))
    '''
    for j in range(np.size(V_t)):
        if j== 0:
            v_t[j] = V_t[j]
        elif j<7:
            v_t[j] = np.mean(V_t[0:j+1])
        elif j!= np.size(V_t)-1:
            v_t[j] = np.mean(V_t[j-6:j+1]) 
        elif j == np.size(V_t)-1:
            v_t[j] = np.mean(V_t[j-6:]) 
    '''
    return V_t

# %%
def get_delta_W_t(length,R0):
    
    delta_W_t = 0
    shape = 3.6
    scale = 120
    for i in range(length):
        delta_W_t += (shape/scale)*(((i+1)/scale)**(shape-1))*math.exp(-((i+1)/scale)**shape)
        
    return delta_W_t*R0

# %%
## input - S0,E0,I0,R0,CIR0,N for a given district with index idx 


def SEIRV_Model(beta,S0,E0,I0,R0,N,idx,flag):
    
    #beta = beta[0]
    #trec = data_preprocessing()[3]
    #print(beta,S0,E0,I0,R0,N,idx,flag)
    
    if flag == 1:
        
        start = datetime(2020,10,11)
        end = datetime(2020,11,1) 
        duration = int((end-start).total_seconds()/(60*60*24))+1
    
    elif flag == 2:
        
        start_simulation = datetime(2020,11,1)
        end_simulation = datetime(2021,2,28)
        vacc_start = datetime(2021,1,18)
        start_idx = int((vacc_start - start_simulation).total_seconds()/(60*60*24))
        duration = int((end_simulation - start_simulation).total_seconds()/(60*60*24))+1
        V_t = get_v_t(idx)
        #print(V_t)
        
    elif flag == 3:
        
        start_simulation = datetime(2021,2,28)
        end_simulation = datetime(2021,3,15)
        vacc_start = datetime(2021,1,18)
        start_idx = int(( start_simulation - vacc_start).total_seconds()/(60*60*24))
        duration = int((end_simulation - start_simulation).total_seconds()/(60*60*24))+1
        V_t = get_v_t(idx)
    
    elif flag == 4:
        
        start_simulation = datetime(2021,3,15)
        end_simulation = datetime(2021,4,7)
        vacc_start = datetime(2021,1,18)
        start_idx = int(( start_simulation - vacc_start).total_seconds()/(60*60*24))
        duration = int((end_simulation - start_simulation).total_seconds()/(60*60*24))+1
        V_t = get_v_t(idx)
        
    S_t = np.zeros(duration)
    S_t[0] = S0
    E_t = np.zeros(duration)
    E_t[0] = E0
    I_t = np.zeros(duration)
    I_t[0] = I0
    R_t = np.zeros(duration)
    R_t[0] = R0
    #st = np.where(trec['Date'] == '01-11-2020')[0][0]
    delta_V_t = 0 
    delta_W_t = 0 
    
    for i in range(0,duration-1):
        
        '''
        if flag == 1:
            delta_W_t = trec[i+203 - 109,idx] - trec[i+203 - 110,idx]
        ''' 
        
        if flag == 2:
            if i < start_idx:
                delta_V_t = 0
            else :
                delta_V_t = V_t[i-start_idx]
            
        elif flag == 3 or flag == 4:
            
            delta_V_t = V_t[i + start_idx ] 
            
   #     if i >0:
    #        delta_W_t = get_delta_W_t(duration-i,R_t[i-1])
            
           
        '''       
        if i<110:
            delta_W_t = trec.iloc[i + st - 109][1+idx] - trec.iloc[i + st-110][1+idx]
        else:
            delta_W_t = R_t[i-109] - R_t[i-110]
        )
        '''
        #print( S_t[i],  beta,I_t[i]/N,epsilon*delta_V_t )
        S_t[i+1] = S_t[i] - beta*S_t[i]*(I_t[i]/N) - epsilon*delta_V_t + delta_W_t
        E_t[i+1] = E_t[i] + beta*S_t[i]*(I_t[i]/N) - alpha*E_t[i]
        I_t[i+1] = I_t[i] + alpha*E_t[i] - gamma*I_t[i]
        R_t[i+1] = R_t[i] + gamma*I_t[i] +  epsilon*delta_V_t  - delta_W_t
    
    return S_t,E_t,I_t,R_t

# %%
## idx - index of district
def loss_function(beta,S0,E0,I0,R0,CIR0,N,idx,flag):
    
    #print(beta,S0,E0,I0,R0,N,idx,flag)
    if flag == 1:
        start = datetime(2020,10,11)
        end = datetime(2020,11,1)
    elif flag == 2:
        start = datetime(2020,11,1)
        end = datetime(2021,2,28)
    elif flag == 3:
        start = datetime(2021,2,28)
        end = datetime(2021,3,15)
    elif flag == 4:
        start = datetime(2021,3,15)
        end = datetime(2021,4,7)
        
    CIR_t = get_CIR_t(CIR0,flag) # on 1st Novemeber
    c_t   = get_c_t(idx,flag)
    duration = int((end-start).total_seconds()/(60*60*24))+1 ## inclusive of start and end
    
    E_t   = SEIRV_Model(beta,S0,E0,I0,R0,N,idx,flag)[1]

    
    '''
    if flag == 1 or flag ==2:
        
        E_t   = SEIRV_Model(beta,S0,E0,I0,R0,N,idx,flag)[1]
        
    elif flag == 3:
        
        E_t   = SEIRV_Model2(beta,S0,E0,I0,R0,N,flag)[1]
    '''
    
    if flag == 1 or flag == 3:
        
        e_t = E_t[-1]/CIR_t[-1] # on 1st November
        cases_1stNov = c_t[-1]
        loss  = abs(alpha*e_t/cases_1stNov-1)
        #print(idx,alpha*e_t,cases_1stNov,loss)
        
    elif flag == 2 or flag ==4:
        e_t = E_t/CIR_t # on 1st November
        mean_e_t = np.zeros(duration) ## mean of delta i(t) from t-6 to t day
        for i in range(duration):
            if i<7:
                mean_e_t[i] = max(np.mean(e_t[0:i+1]),1/alpha)
            elif i!= duration-1:
                mean_e_t[i] = max(np.mean(e_t[i-6:i+1]),1/alpha)
            elif i == duration-1:
                mean_e_t[i] = max(np.mean(e_t[i-6:]),1/alpha)

        loss  = np.sum(np.square(np.log(alpha*e_t) - np.log(c_t)))/duration
        
    return loss

# %%
## since mobility is identity so minimized independently over all districts
def minimizer(S0,E0,I0,R0,CIR0,N,flag):
    
    num_units = np.size(S0)
    beta = np.zeros(num_units)
    #if flag == 1 or flag == 2:
        
    for i in range(num_units):
        sol = minimize(loss_function,x0 = 0.5,args = (S0[i],E0[i],I0[i],R0[i],CIR0[i],N[i],i,flag),bounds = [[0,1]])
        beta[i] = sol.x
        print(i,sol.fun)
    '''       
    else if flag == 3:
        
        for i in range(num_units):
            sol = minimize(loss_function,x0 = 0.5,args = (S0,E0,I0,R0,CIR0,N,i,flag),bounds = [[0,1]]
                          )
            beta[i] = sol.x
            print(i,sol.fun)
    '''
    return beta

# %%
'''
for i in range(38):
    #cases = tinf.to_numpy()[start_idx:end_idx+1,1:] - trec.to_numpy()[start_idx:end_idx+1,1:] - tdec.to_numpy()[start_idx:end_idx+1,1:]
    y = get_c_t(i,2)
    x = np.arange(1,len(y)+1)
    plt.figure()
    plt.plot(x,y)
    plt.show()
    plt.close()
'''    
S0,E0,I0,R0,CIR0,N = initial_conditions(1)
#print(E0)
#print(S0,E0,I0,R0)
beta = minimizer(S0,E0,I0,R0,CIR0,N,1)
print(beta)

'''
beta  = np.array([0.006, 0.01 , 0.013, 0.019,0.018, 0.019, 0.02, 0.014, 0.014, 0.021,
 0.014, 0.014, 0.01, 0.007, 0.017, 0.01, 0.008, 0.021, 0.017,
 0.015, 0.023, 0.017, 0.01, 0.011, 0.009, 0.017, 0.011, 0.012,
 0.025, 0.007])
'''
# Out:
# 0 0.4851992246554596
# 1 2.927399656016405e-09
# 2 0.22568593614511467
# 3 1.5597914515552702e-08
# 4 0.5517282496008986
# 5 0.7963872883460829
# 6 0.7232248903148499
# 7 9.94408022592097e-09
# 8 1.2267785343134108e-08
# 9 5.114601631106552e-09
# 10 2.646024843677708e-08
# 11 0.8737651459955846
# 12 8.858261901778519e-09
# 13 1.5935397446042998e-08
# 14 1.7767700088988647e-08
# 15 1.1640418406955177e-08
# 16 0.26664945320594124
# 17 0.2958451446426156
# 18 4.166417877371487e-09
# 19 0.24194775518064693
# 20 8.345232727080543e-09
# 21 6.38759654059129e-08
# 22 0.5202755130835255
# 23 3.703586859415964e-08
# 24 1.0834041663798644e-08
# 25 1.7911287342187165e-08
# 26 4.1167069753100805e-13
# 27 3.870671316796859e-08
# 28 1.3956249489410766e-09
# 29 2.2449581082994996e-09
# 30 6.399131446954698e-09
# 31 7.809668356451027e-09
# 32 0.43289228916889977
# 33 0.6561583664230058
# 34 4.434665856756226e-09
# 35 3.5759053385042705e-08
# 36 4.418614696355405e-09
# 37 1.4203438314375205e-08
# [0.58016 0.47636 0.8733  0.38674 0.5407  0.63228 0.68288 0.41706 0.1035
#  0.43705 0.31746 0.55591 0.45045 0.2154  0.31039 0.17363 0.51328 0.53382
#  0.39461 0.48853 0.16173 0.15348 0.5051  0.20064 0.25212 0.34492 0.33845
#  0.24312 0.84672 0.32037 0.24714 0.42425 1.      0.46252 0.3221  0.23527
#  0.53816 0.22852]
# '\nbeta  = np.array([0.006, 0.01 , 0.013, 0.019,0.018, 0.019, 0.02, 0.014, 0.014, 0.021,\n 0.014, 0.014, 0.01, 0.007, 0.017, 0.01, 0.008, 0.021, 0.017,\n 0.015, 0.023, 0.017, 0.01, 0.011, 0.009, 0.017, 0.011, 0.012,\n 0.025, 0.007])\n'

# %%
## Code for prediction on 1st November obtaining new S0,E0,I0,R0,CIR0 for next phase 
for i in range(np.size(S0)):
    S,E,I,R,  = SEIRV_Model(beta[i],S0[i],E0[i],I0[i],R0[i],N[i],i,1)
    CIR0[i] = get_CIR_t(CIR0[i],1)[-1]
    actual = get_c_t(i,1)[-1]
    S0[i] = S[-1] ## S at 1st November
    E0[i] = E[-1]
    I0[i] = I[-1]
    R0[i] = R[-1]
    predicted = alpha*E0[i]/CIR0[i]
    print( 'predicted cases on 1st November for district %d = %f and actual is %f'%(i,predicted,actual))
    
## minimization from 1st to 28th February
beta = minimizer(S0,E0,I0,R0,CIR0,N,2)

## Code for prediction on 1st March obtaining new S0,E0,I0,R0,CIR0 for next phase 
for i in range(np.size(S0)):
    
    S,E,I,R,  = SEIRV_Model(beta[i],S0[i],E0[i],I0[i],R0[i],N[i],i,2)
    CIR0[i] = get_CIR_t(CIR0[i],2)[-1]
    actual = get_c_t(i,2)[-1]
    S0[i] = S[-1] ## S at 28th Feb
    E0[i] = E[-1]
    I0[i] = I[-1]
    R0[i] = R[-1]
    predicted = alpha*E0[i]/CIR0[i]
    print('predicted cases on 28th Feb 2021 for district %d = %f and actual is %f'%(i,predicted,actual))

## minimization from 1st march to 15th march

beta = minimizer(S0,E0,I0,R0,CIR0,N,3)

for i in range(np.size(S0)):
    S,E,I,R,  = SEIRV_Model(beta[i],S0[i],E0[i],I0[i],R0[i],N[i],i,3)
    CIR0[i] = get_CIR_t(CIR0[i],3)[-1]
    actual = get_c_t(i,3)[-1]
    S0[i] = S[-1]
    E0[i] = E[-1]
    I0[i] = I[-1]
    R0[i] = R[-1]
    predicted = alpha*E0[i]/CIR0[i]
    print( 'predicted cases on 15th march for district %d = %f and actual is %f'%(i,predicted,actual))

beta = minimizer(S0,E0,I0,R0,CIR0,N,4)

for i in range(np.size(S0)):
    S,E,I,R,  = SEIRV_Model(beta[i],S0[i],E0[i],I0[i],R0[i],N[i],i,4)
    CIR0[i] = get_CIR_t(CIR0[i],4)[-1]
    actual = get_c_t(i,4)[-1]
    S0[i] = S[-1]
    E0[i] = E[-1]
    I0[i] = I[-1]
    R0[i] = R[-1]
    predicted = alpha*E0[i]/CIR0[i]
    print( 'predicted cases on 7th April for district %d = %f and actual is %f'%(i,predicted,actual))
# Out:
# predicted cases on 1st November for district 0 = 920.839080 and actual is 1740.308923
# predicted cases on 1st November for district 1 = 855.736677 and actual is 845.383016
# predicted cases on 1st November for district 2 = 2497.636917 and actual is 3201.040089
# predicted cases on 1st November for district 3 = 1739.120690 and actual is 1692.028522
# predicted cases on 1st November for district 4 = 637.444219 and actual is 1411.188275
# predicted cases on 1st November for district 5 = 764.118774 and actual is 3696.845702
# predicted cases on 1st November for district 6 = 703.782961 and actual is 2403.280223
# predicted cases on 1st November for district 7 = 1089.559387 and actual is 1040.793180
# predicted cases on 1st November for district 8 = 135.676393 and actual is 132.857143
# predicted cases on 1st November for district 9 = 597.081581 and actual is 583.285714
# predicted cases on 1st November for district 10 = 469.706258 and actual is 467.571429
# predicted cases on 1st November for district 11 = 369.725906 and actual is 2899.142857
# predicted cases on 1st November for district 12 = 1777.279693 and actual is 1697.714286
# predicted cases on 1st November for district 13 = 44.521073 and actual is 43.857143
# predicted cases on 1st November for district 14 = 166.955907 and actual is 165.142857
# predicted cases on 1st November for district 15 = 212.113943 and actual is 203.428571
# predicted cases on 1st November for district 16 = 288.208396 and actual is 390.857143
# predicted cases on 1st November for district 17 = 355.299330 and actual is 499.000000
# predicted cases on 1st November for district 18 = 1006.355529 and actual is 1002.142857
# predicted cases on 1st November for district 19 = 311.089785 and actual is 409.571429
# predicted cases on 1st November for district 20 = 286.175549 and actual is 282.714286
# predicted cases on 1st November for district 21 = 138.119122 and actual is 126.714286
# predicted cases on 1st November for district 22 = 524.440820 and actual is 1073.285714
# predicted cases on 1st November for district 23 = 147.459016 and actual is 145.857143
# predicted cases on 1st November for district 24 = 386.514537 and actual is 383.571429
# predicted cases on 1st November for district 25 = 147.248716 and actual is 144.285714
# predicted cases on 1st November for district 26 = 416.120690 and actual is 411.714286
# predicted cases on 1st November for district 27 = 171.163793 and actual is 168.285714
# predicted cases on 1st November for district 28 = 806.544228 and actual is 802.142857
# predicted cases on 1st November for district 29 = 1090.850178 and actual is 1086.285714
# predicted cases on 1st November for district 30 = 182.984085 and actual is 182.714286
# predicted cases on 1st November for district 31 = 223.615385 and actual is 223.285714
# predicted cases on 1st November for district 32 = 846.637931 and actual is 578.571429
# predicted cases on 1st November for district 33 = 429.224138 and actual is 1244.142857
# predicted cases on 1st November for district 34 = 359.500595 and actual is 358.000000
# predicted cases on 1st November for district 35 = 387.493842 and actual is 383.857143
# predicted cases on 1st November for district 36 = 335.108893 and actual is 331.857143
# predicted cases on 1st November for district 37 = 160.601822 and actual is 160.285714
# 0 nan
# C:\Users\Asus\AppData\Local\Temp/ipykernel_16996/383020502.py:53: RuntimeWarning: invalid value encountered in log
#   loss  = np.sum(np.square(np.log(alpha*e_t) - np.log(c_t)))/duration
# 1 20.745086460064126
# 2 nan
# 3 13.904262429659335
# 4 nan
# 5 nan
# 6 nan
# 7 11.770225743172425
# 8 nan
# 9 16.153953499378257
# 10 2.499209383575413
# 11 43.79689152239722
# 12 nan
# 13 0.208586606930579
# 14 3.9903618472186677
# 15 0.1158407098344504
# 16 nan
# 17 nan
# 18 nan
# 19 30.873042268534572
# 20 0.3140196459258482
# 21 nan
# 22 nan
# 23 0.5007791058934705
# 24 4.831228992741789
# 25 12.455639795408452
# 26 4.653519943735322
# 27 nan
# 28 nan
# 29 5.812976175584409
# 30 0.8995798876255313
# 31 11.174879757066318
# 32 nan
# 33 nan
# 34 nan
# 35 1.005486808742143
# 36 22.172807335387844
# 37 1.3849454084261146
# predicted cases on 28th Feb 2021 for district 0 = 0.000000 and actual is 482.856631
# predicted cases on 28th Feb 2021 for district 1 = 0.014368 and actual is 234.555365
# predicted cases on 28th Feb 2021 for district 2 = 0.000000 and actual is 888.143142
# predicted cases on 28th Feb 2021 for district 3 = 0.188088 and actual is 469.461014
# predicted cases on 28th Feb 2021 for district 4 = 0.000000 and actual is 391.540610
# predicted cases on 28th Feb 2021 for district 5 = 0.000000 and actual is 1025.706665
# predicted cases on 28th Feb 2021 for district 6 = 0.000000 and actual is 666.801036
# predicted cases on 28th Feb 2021 for district 7 = 0.189655 and actual is 288.772805
# predicted cases on 28th Feb 2021 for district 8 = 6.111772 and actual is 4.285714
# predicted cases on 28th Feb 2021 for district 9 = 0.007337 and actual is 75.714286
# predicted cases on 28th Feb 2021 for district 10 = 2.208009 and actual is 103.000000
# predicted cases on 28th Feb 2021 for district 11 = 0.000000 and actual is 74.285714
# predicted cases on 28th Feb 2021 for district 12 = 0.034483 and actual is 471.571429
# predicted cases on 28th Feb 2021 for district 13 = 23.631813 and actual is 96.571429
# predicted cases on 28th Feb 2021 for district 14 = 0.317734 and actual is 31.285714
# predicted cases on 28th Feb 2021 for district 15 = 16.830239 and actual is 35.142857
# predicted cases on 28th Feb 2021 for district 16 = 0.000000 and actual is 17.571429
# predicted cases on 28th Feb 2021 for district 17 = 0.000000 and actual is 74.428571
# predicted cases on 28th Feb 2021 for district 18 = 0.031348 and actual is 217.714286
# predicted cases on 28th Feb 2021 for district 19 = 0.000000 and actual is 27.000000
# predicted cases on 28th Feb 2021 for district 20 = 23.074713 and actual is 60.714286
# predicted cases on 28th Feb 2021 for district 21 = 5.028736 and actual is 14.000000
# predicted cases on 28th Feb 2021 for district 22 = 0.000000 and actual is 82.857143
# predicted cases on 28th Feb 2021 for district 23 = 1.413793 and actual is 4.428571
# predicted cases on 28th Feb 2021 for district 24 = 1.432818 and actual is 198.714286
# predicted cases on 28th Feb 2021 for district 25 = 0.044700 and actual is 59.857143
# predicted cases on 28th Feb 2021 for district 26 = 0.353902 and actual is 35.428571
# predicted cases on 28th Feb 2021 for district 27 = 3.539272 and actual is 6.428571
# predicted cases on 28th Feb 2021 for district 28 = 0.000000 and actual is 23.142857
# predicted cases on 28th Feb 2021 for district 29 = 0.888192 and actual is 154.857143
# predicted cases on 28th Feb 2021 for district 30 = 1.248835 and actual is 20.571429
# predicted cases on 28th Feb 2021 for district 31 = 0.002330 and actual is 8.571429
# predicted cases on 28th Feb 2021 for district 32 = 0.000000 and actual is 40.714286
# predicted cases on 28th Feb 2021 for district 33 = 0.000000 and actual is 182.000000
# predicted cases on 28th Feb 2021 for district 34 = 0.026123 and actual is 94.428571
# predicted cases on 28th Feb 2021 for district 35 = 3.184267 and actual is 35.714286
# predicted cases on 28th Feb 2021 for district 36 = 0.001582 and actual is 60.142857
# predicted cases on 28th Feb 2021 for district 37 = 0.604862 and actual is 12.428571
# 0 1.0
# 1 1.0000015882223925
# 2 1.0
# 3 0.9999946158678082
# 4 1.0
# 5 1.0
# 6 1.0
# 7 0.9999879169811033
# 8 0.9487073843421165
# 9 1.0000009902158675
# 10 0.9920364511489812
# 11 1.0
# 12 1.0000024475844524
# 13 0.5119399865949045
# 14 0.993724380039954
# 15 0.14664229657979744
# 16 1.0
# 17 1.0
# 18 1.0000064532796469
# 19 1.0
# 20 1.4134310166724617e-08
# 21 0.9892687715168106
# 22 1.0
# 23 0.5289634292125802
# 24 0.9981384308695137
# 25 0.9999645634715524
# 26 0.9981592160897345
# 27 0.9349260660169114
# 28 1.0
# 29 0.9995686564666489
# 30 0.9822462468278323
# 31 1.0000014711642966
# 32 1.0
# 33 1.0
# 34 1.0000066326422485
# 35 0.9427080032677179
# 36 0.9999999514190228
# 37 0.9845786663609911
# predicted cases on 15th march for district 0 = 0.000000 and actual is 1004.391157
# predicted cases on 15th march for district 1 = 0.000000 and actual is 487.899139
# predicted cases on 15th march for district 2 = 0.000000 and actual is 1847.428533
# predicted cases on 15th march for district 3 = 0.000000 and actual is 976.526904
# predicted cases on 15th march for district 4 = 0.000000 and actual is 814.444497
# predicted cases on 15th march for district 5 = 0.000000 and actual is 2133.574726
# predicted cases on 15th march for district 6 = 0.000000 and actual is 1387.014324
# predicted cases on 15th march for district 7 = 0.000000 and actual is 600.676956
# predicted cases on 15th march for district 8 = 1.961207 and actual is 37.142857
# predicted cases on 15th march for district 9 = 0.000000 and actual is 133.285714
# predicted cases on 15th march for district 10 = 1.444784 and actual is 180.857143
# predicted cases on 15th march for district 11 = 0.000000 and actual is 240.571429
# predicted cases on 15th march for district 12 = 0.000000 and actual is 980.285714
# predicted cases on 15th march for district 13 = 176.555040 and actual is 355.714286
# predicted cases on 15th march for district 14 = 0.251315 and actual is 39.857143
# predicted cases on 15th march for district 15 = 77.045455 and actual is 89.571429
# predicted cases on 15th march for district 16 = 0.000000 and actual is 54.428571
# predicted cases on 15th march for district 17 = 0.000000 and actual is 86.285714
# predicted cases on 15th march for district 18 = 0.000000 and actual is 531.714286
# predicted cases on 15th march for district 19 = 0.000000 and actual is 54.857143
# predicted cases on 15th march for district 20 = 143.879310 and actual is 140.571429
# predicted cases on 15th march for district 21 = 0.344828 and actual is 32.142857
# predicted cases on 15th march for district 22 = 0.000000 and actual is 238.571429
# predicted cases on 15th march for district 23 = 2.995324 and actual is 6.285714
# predicted cases on 15th march for district 24 = 0.971147 and actual is 517.142857
# predicted cases on 15th march for district 25 = 0.000000 and actual is 73.000000
# predicted cases on 15th march for district 26 = 0.201149 and actual is 109.285714
# predicted cases on 15th march for district 27 = 1.293103 and actual is 19.428571
# predicted cases on 15th march for district 28 = 0.000000 and actual is 120.142857
# predicted cases on 15th march for district 29 = 0.160099 and actual is 370.714286
# predicted cases on 15th march for district 30 = 0.826492 and actual is 46.571429
# predicted cases on 15th march for district 31 = 0.000000 and actual is 18.142857
# predicted cases on 15th march for district 32 = 0.000000 and actual is 88.000000
# predicted cases on 15th march for district 33 = 0.000000 and actual is 341.000000
# predicted cases on 15th march for district 34 = 0.000000 and actual is 379.142857
# predicted cases on 15th march for district 35 = 3.007663 and actual is 52.000000
# predicted cases on 15th march for district 36 = 0.000000 and actual is 162.000000
# predicted cases on 15th march for district 37 = 0.497347 and actual is 32.428571
# 0 nan
# 1
# C:\Users\Asus\AppData\Local\Temp/ipykernel_16996/383020502.py:53: RuntimeWarning: divide by zero encountered in log
#   loss  = np.sum(np.square(np.log(alpha*e_t) - np.log(c_t)))/duration
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\scipy\optimize\_numdiff.py:557: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# nan
# 2 nan
# 3 nan
# 4 nan
# 5 nan
# 6 nan
# 7 nan
# 8 nan
# 9 nan
# 10 nan
# 11 nan
# 12 nan
# 13 2.900320131326214
# 14 nan
# 15 nan
# 16 nan
# 17 nan
# 18 nan
# 19 nan
# 20 0.12477342039249983
# 21 nan
# 22 nan
# 23 9.423570395642537
# 24 nan
# 25 nan
# 26 nan
# 27 nan
# 28 nan
# 29 nan
# 30 nan
# 31 nan
# 32 nan
# 33 nan
# 34 nan
# 35 nan
# 36 nan
# 37 nan
# predicted cases on 7th April for district 0 = 0.000000 and actual is 6558.932297
# predicted cases on 7th April for district 1 = 0.000000 and actual is 3186.106726
# predicted cases on 7th April for district 2 = 0.000000 and actual is 12064.182944
# predicted cases on 7th April for district 3 = 0.000000 and actual is 6376.971567
# predicted cases on 7th April for district 4 = 0.000000 and actual is 5318.531802
# predicted cases on 7th April for district 5 = 0.000000 and actual is 13932.791098
# predicted cases on 7th April for district 6 = 0.000000 and actual is 9057.559877
# predicted cases on 7th April for district 7 = 0.000000 and actual is 3922.574843
# predicted cases on 7th April for district 8 = -0.098522 and actual is 251.285714
# predicted cases on 7th April for district 9 = 0.000000 and actual is 1090.571429
# predicted cases on 7th April for district 10 = -0.080704 and actual is 685.000000
# predicted cases on 7th April for district 11 = 0.000000 and actual is 1260.571429
# predicted cases on 7th April for district 12 = 0.000000 and actual is 6396.285714
# predicted cases on 7th April for district 13 = 39.243604 and actual is 2219.571429
# predicted cases on 7th April for district 14 = -0.019704 and actual is 337.142857
# predicted cases on 7th April for district 15 = -4.549072 and actual is 603.142857
# predicted cases on 7th April for district 16 = 0.000000 and actual is 405.285714
# predicted cases on 7th April for district 17 = 0.000000 and actual is 162.857143
# predicted cases on 7th April for district 18 = 0.000000 and actual is 1239.571429
# predicted cases on 7th April for district 19 = 0.000000 and actual is 348.428571
# predicted cases on 7th April for district 20 = 330.747126 and actual is 868.571429
# predicted cases on 7th April for district 21 = 0.000000 and actual is 149.000000
# predicted cases on 7th April for district 22 = 0.000000 and actual is 1245.142857
# predicted cases on 7th April for district 23 = 0.182266 and actual is 174.285714
# predicted cases on 7th April for district 24 = -0.029727 and actual is 2461.428571
# predicted cases on 7th April for district 25 = 0.000000 and actual is 192.714286
# predicted cases on 7th April for district 26 = -0.012315 and actual is 475.000000
# predicted cases on 7th April for district 27 = -0.047893 and actual is 358.571429
# predicted cases on 7th April for district 28 = 0.000000 and actual is 711.428571
# predicted cases on 7th April for district 29 = 0.000000 and actual is 2395.571429
# predicted cases on 7th April for district 30 = -0.051258 and actual is 497.571429
# predicted cases on 7th April for district 31 = 0.000000 and actual is 362.571429
# predicted cases on 7th April for district 32 = 0.000000 and actual is 522.714286
# predicted cases on 7th April for district 33 = 0.000000 and actual is 2469.000000
# predicted cases on 7th April for district 34 = 0.000000 and actual is 477.285714
# predicted cases on 7th April for district 35 = -0.150862 and actual is 421.285714
# predicted cases on 7th April for district 36 = 0.000000 and actual is 757.428571
# predicted cases on 7th April for district 37 = -0.033370 and actual is 396.857143
